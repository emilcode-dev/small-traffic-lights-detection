# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/emilcode-dev/small-traffic-lights-detection/blob/dev/init-colab-uv-setup/notebooks/project-experiments.ipynb)

# %%
# !git clone https://github.com/emilcode-dev/small-traffic-lights-detection.git
# %cd small-traffic-lights-detection
# !git checkout dev/init-colab-uv-setup

# %%
# !pip install uv

# %%
# !uv pip install .

# %%
import trafficlightdetect as tld

# %%
tld.something("This is a test.")
